# %% [markdown]
# ### Importando arquivos CSV

# %%
import pandas as pd# importing the pandas library

#importing the data
arquivo = "dados/arquivo_csv_virgula.csv" #path to the file
#pd.read_csv(arquivo) #reading the file

# %%
funcionario = pd.read_csv(arquivo)# reading the file
funcionario.head() #showing the first 5 lines of the file
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva     54         2.270   Feminino       São Paulo     SP
# 1  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos     46         8.657  Masculino  Belo Horizonte     MG
# 3       Ana Costa     30         5.026   Feminino        Salvador     BA
# 4   Lucas Pereira     39         4.128  Masculino        Curitiba     PR
#
#            Data de Nascimento
# 0  1970-06-15 22:19:00.037648
# 1  1944-06-15 10:19:00.037648
# 2  1978-06-15 22:19:00.037648
# 3  1994-06-15 22:19:00.037648
# 4  1985-06-15 16:19:00.037648

# %%
funcionario.dtypes #showing the data types of the columns
# Out:
# Nome Completo          object
# Idade                   int64
# Renda Mensal          float64
# Sexo                   object
# Cidade                 object
# Estado                 object
# Data de Nascimento     object
# dtype: object

# %%
# adding params to the read_csv function
funcionario = pd.read_csv(arquivo, sep= ',', parse_dates=['Data de Nascimento'], encoding="utf-8", thousands=".", decimal=",", dtype={"Idade":float})# reading the file with specific parameters
funcionario.head()
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva   54.0           227   Feminino       São Paulo     SP
# 1  Maria Oliveira   80.0          5147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos   46.0          8657  Masculino  Belo Horizonte     MG
# 3       Ana Costa   30.0          5026   Feminino        Salvador     BA
# 4   Lucas Pereira   39.0          4128  Masculino        Curitiba     PR
#
#           Data de Nascimento
# 0 1970-06-15 22:19:00.037648
# 1 1944-06-15 10:19:00.037648
# 2 1978-06-15 22:19:00.037648
# 3 1994-06-15 22:19:00.037648
# 4 1985-06-15 16:19:00.037648

# %%
funcionario.dtypes #showing the data types of the columns again to see the changes
# Out:
# Nome Completo                 object
# Idade                        float64
# Renda Mensal                   int64
# Sexo                          object
# Cidade                        object
# Estado                        object
# Data de Nascimento    datetime64[ns]
# dtype: object

# %%
# importando o arquivo com o separador de ponto e vírgula
# importing the file with the semicolon separator
arquivo_pv = "dados/arquivo_csv_ponto_virgula.csv" #path to the file
funcionario_pv = pd.read_csv(arquivo_pv)# reading the file
funcionario_pv.head()
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva     54         2.270   Feminino       São Paulo     SP
# 1  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos     46         8.657  Masculino  Belo Horizonte     MG
# 3       Ana Costa     30         5.026   Feminino        Salvador     BA
# 4   Lucas Pereira     39         4.128  Masculino        Curitiba     PR
#
#            Data de Nascimento
# 0  1970-06-15 22:19:00.037648
# 1  1944-06-15 10:19:00.037648
# 2  1978-06-15 22:19:00.037648
# 3  1994-06-15 22:19:00.037648
# 4  1985-06-15 16:19:00.037648

# %%
# Importando arquivo com pipe
# importing file with pipe
arquivo_txt = "dados/arquivo_csv_ponto_pipe.txt"#path to the file
funcionario_txt = pd.read_csv(arquivo_txt, sep='|')# reading the file with pipe separator
funcionario_txt.head() #showing the first 5 lines of the file with pipe separator
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva     54         2.270   Feminino       São Paulo     SP
# 1  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos     46         8.657  Masculino  Belo Horizonte     MG
# 3       Ana Costa     30         5.026   Feminino        Salvador     BA
# 4   Lucas Pereira     39         4.128  Masculino        Curitiba     PR
#
#            Data de Nascimento
# 0  1970-06-15 22:19:00.037648
# 1  1944-06-15 10:19:00.037648
# 2  1978-06-15 22:19:00.037648
# 3  1994-06-15 22:19:00.037648
# 4  1985-06-15 16:19:00.037648

# %%
# importing excel file
# importing archivo excel
arquivo_excel = "dados/vendas_2022.xlsx" #path to the file
vendas = pd.read_excel(arquivo_excel)# reading the excel file
vendas.head() #showing the first 5 lines of the excel file
# Out:
#    Order Id      Product Id  Prod. Costs  Rent Costs           Sales Date  \
# 0  32899284  BL01-CA03-1101       637.11         0.0  2022-02-09 00:00:00
# 1  32882015  BL01-CA03-1076       445.16         0.0  2022-01-21 00:00:00
# 2  32961417  BL01-CA03-1076       445.16         0.0  2022-05-20 00:00:00
# 3  33015853  BL01-CA03-1076       445.16         0.0  2022-08-02 00:00:00
# 4  32981117  BL01-CA03-1040      2289.20         0.0  2022-06-21 00:00:00
#
#    Fiscal Year  Total Cost  Customer Id  Volume (LB)  Volume  ...  \
# 0         2023      169.54         4564            0       0  ...
# 1         2023       95.84         4564         5290       0  ...
# 2         2023       99.76         4564         5290       0  ...
# 3         2023       99.76         4564         5290       0  ...
# 4         2023       61.20         4564          480       0  ...
#
#                     City Latitude  Longitude   GEO ZONE Plant Name  \
# ...

# %%
import json
# importing json file

# %% [markdown]
# ### importando json

# %%
arquivo_json = "dados/arquivo_JSON.json" #path to the file

with open(arquivo_json, 'r') as file:
    dados_json = json.load(file) # reading the json file
dados_json #showing the json data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'bbox': [-87.376881, 36.017586, -86.857498, 36.179398],
#    'type': 'Feature',
#    'properties': {'segments': [{'distance': 60837.7,
#       'duration': 2541.5,
#       'steps': [{'distance': 25.0,
#         'duration': 4.5,
#         'type': 11,
#         'instruction': 'Head east on Hermitage Plaza',
#         'name': 'Hermitage Plaza',
#         'way_points': [0, 2]},
#        {'distance': 555.6,
#         'duration': 100.0,
#         'type': 1,
#         'instruction': 'Turn right onto Centennial Place',
#         'name': 'Centennial Place',
#         'way_points': [2, 8]},
#        {'distance': 527.0,
#         'duration': 41.2,
#         'type': 5,
#         'instruction': 'Turn slight right onto Centennial Boulevard',
#         'name': 'Centennial Boulevard',
#         'way_points': [8, 24]},
#        {'distance': 252.8,
#         'duration': 18.2,
#         'type': 0,
# ...
