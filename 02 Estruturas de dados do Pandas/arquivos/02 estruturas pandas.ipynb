# %%
import pandas as pd

# %%
path_csv = 'dados/01 dados_exemplo.csv'

dados = pd.read_csv(path_csv)

# %%
dados
# Out:
#         Nome          Cidade  Idade  Renda Mensal Sexo Estado Civil  \
# 0        Ana        Brasília     62          8599    M        Viúvo
# 1       João          Manaus     18          3496    M     Solteiro
# 2      Maria          Manaus     21          9291    F   Divorciado
# 3      Pedro        Curitiba     21         11200    F     Solteiro
# 4      Lucas  Belo Horizonte     57          1755    M        Viúvo
# 5      Laura        Curitiba     27          1797    F        Viúvo
# 6    Mariana        Brasília     37          1659    M     Solteiro
# 7     Carlos        Curitiba     39          4219    M        Viúvo
# 8      Paula        Brasília     54          9615    F     Solteiro
# 9       José        Salvador     41          8456    M     Solteiro
# 10  Fernanda       Fortaleza     24          4337    F     Solteiro
# 11    Rafael       São Paulo     42          3745    F     Solteiro
# 12   Gabriel          Manaus     42          5735    F   Divorciado
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.dtypes
# Out:
# Nome            object
# Cidade          object
# Idade            int64
# Renda Mensal     int64
# Sexo            object
# Estado Civil    object
# Qtd Filhos       int64
# dtype: object

# %%
dados.columns
# Out:
# Index(['Nome', 'Cidade', 'Idade', 'Renda Mensal', 'Sexo', 'Estado Civil',
#        'Qtd Filhos'],
#       dtype='object')

# %%
dados.head()
# Out:
#     Nome          Cidade  Idade  Renda Mensal Sexo Estado Civil  Qtd Filhos
# 0    Ana        Brasília     62          8599    M        Viúvo           0
# 1   João          Manaus     18          3496    M     Solteiro           1
# 2  Maria          Manaus     21          9291    F   Divorciado           2
# 3  Pedro        Curitiba     21         11200    F     Solteiro           4
# 4  Lucas  Belo Horizonte     57          1755    M        Viúvo           2

# %%
dados.tail(10)
# Out:
#        Nome        Cidade  Idade  Renda Mensal Sexo Estado Civil  Qtd Filhos
# 20   Mateus     Fortaleza     35         12122    M       Casado           3
# 21  Beatriz      Salvador     55          2207    F       Casado           3
# 22  Gustavo      Curitiba     43          7172    M     Solteiro           3
# 23    Luiza  Porto Alegre     31          9994    M       Casado           2
# 24   Felipe      Salvador     26         11368    F       Casado           3
# 25   Camila      Curitiba     27         11368    F       Casado           4
# 26  Rodrigo      Curitiba     38         11148    M        Viúvo           1
# 27  Vanessa     Fortaleza     34          8221    F     Solteiro           2
# 28   Daniel        Recife     23          7021    M        Viúvo           3
# 29    Aline        Recife     33          4622    M       Casado           1

# %%
pd.pivot_table(
    dados,
    index='Estado Civil',
    values='Nome',
    columns='Sexo',
    aggfunc='count'
)
# Out:
# Sexo          F  M
# Estado Civil
# Casado        3  4
# Divorciado    2  1
# Solteiro      6  4
# Viúvo         5  5

# %%
type(dados['Cidade'])
# Out:
# pandas.core.series.Series

# %%
type(dados[['Cidade']])
# Out:
# pandas.core.frame.DataFrame

# %%
dados['Cidade'].unique()
# Out:
# array(['Brasília', 'Manaus', 'Curitiba', 'Belo Horizonte', 'Salvador',
#        'Fortaleza', 'São Paulo', 'Porto Alegre', 'Recife'], dtype=object)

# %%
dados['Idade'].sum()
# Out:
# 1139

# %%
dados['Idade'].mean()
# Out:
# 37.96666666666667

# %%
dados[['Idade']].mean()
# Out:
# Idade    37.966667
# dtype: float64

# %%
dados['Idade'].unique()
# Out:
# array([62, 18, 21, 57, 27, 37, 39, 54, 41, 24, 42, 30, 19, 56, 64, 35, 55,
#        43, 31, 26, 38, 34, 23, 33], dtype=int64)

# %%
dados.sort_values(by='Idade', ascending=False)
# Out:
#         Nome          Cidade  Idade  Renda Mensal Sexo Estado Civil  \
# 18     Fábio        Curitiba     64         11915    F        Viúvo
# 0        Ana        Brasília     62          8599    M        Viúvo
# 4      Lucas  Belo Horizonte     57          1755    M        Viúvo
# 16   Ricardo          Manaus     57          3292    M   Divorciado
# 15     Bruna        Salvador     56          1714    F        Viúvo
# 21   Beatriz        Salvador     55          2207    F       Casado
# 8      Paula        Brasília     54          9615    F     Solteiro
# 22   Gustavo        Curitiba     43          7172    M     Solteiro
# 19    Amanda          Recife     42         12723    M       Casado
# 11    Rafael       São Paulo     42          3745    F     Solteiro
# 12   Gabriel          Manaus     42          5735    F   Divorciado
# 17   Roberta  Belo Horizonte     41          9343    F        Viúvo
# 9       José        Salvador     41          8456    M     Solteiro
# ...
